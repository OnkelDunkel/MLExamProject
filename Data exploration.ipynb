# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("employee_reviews.csv")

# %%
df.head(1)
# Out:
#    Unnamed: 0 company location          dates  \
# 0           1  google     none   Dec 11, 2018
#
#                                job-title                   summary  \
# 0  Current Employee - Anonymous Employee  Best Company to work for
#
#                             pros                                cons  \
# 0  People are smart and friendly  Bureaucracy is slowing things down
#
#   advice-to-mgmt  overall-ratings work-balance-stars culture-values-stars  \
# 0           none              5.0                4.0                  5.0
#
#   carrer-opportunities-stars comp-benefit-stars senior-mangemnet-stars  \
# 0                        5.0                4.0                    5.0
#
#    helpful-count                                               link
# 0              0  https://www.glassdoor.com/Reviews/Google-Revie...

# %%
df.count()[0]
# Out:
# 67529

# %%
df2 = df[df["work-balance-stars"] == "none"]
df2
# Out:
#        Unnamed: 0    company           location          dates  \
# 15             16     google               none    Dec 6, 2018
# 17             18     google               none    Dec 2, 2018
# 22             23     google               none    Dec 1, 2018
# 23             24     google               none   Nov 30, 2018
# 29             30     google               none   Nov 20, 2018
# 30             31     google               none   Nov 21, 2018
# 40             41     google               none    Dec 4, 2018
# 45             46     google               none   Nov 19, 2018
# 50             51     google               none   Nov 15, 2018
# 51             52     google               none   Nov 27, 2018
# 53             54     google               none   Nov 11, 2018
# 58             59     google               none   Nov 22, 2018
# 60             61     google               none    Nov 6, 2018
# 64             65     google               none    Nov 5, 2018
# ...

# %%
df = df[df["work-balance-stars"] != "none"]
df = df[df["culture-values-stars"] != "none"]
df = df[df["carrer-opportunities-stars"] != "none"]
df = df[df["comp-benefit-stars"] != "none"]
df = df[df["senior-mangemnet-stars"] != "none"]
df.count()[0]
# Out:
# 53222

# %%
df.count()[0]
# Out:
# 53222

# %%
df
# Out:
#        Unnamed: 0    company                location          dates  \
# 0               1     google                    none   Dec 11, 2018
# 1               2     google       Mountain View, CA   Jun 21, 2013
# 2               3     google            New York, NY   May 10, 2014
# 3               4     google       Mountain View, CA    Feb 8, 2015
# 4               5     google         Los Angeles, CA   Jul 19, 2018
# 5               6     google       Mountain View, CA    Dec 9, 2018
# 6               7     google            New York, NY   Dec 11, 2018
# 7               8     google                    none   Dec 11, 2018
# 8               9     google            New York, NY   Dec 10, 2018
# 9              10     google                    none    Dec 9, 2018
# 10             11     google       Mountain View, CA    Dec 8, 2018
# 11             12     google                    none    Dec 8, 2018
# 12             13     google                    none    Dec 4, 2018
# ...

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(15,11))
sns.heatmap(df[df["work-balance-stars", "culture-values-stars", "carrer-opportunities-stars", "comp-benefit-stars", "senior-mangemnet-stars"]].corr().round(2),linewidths=0.50,vmax=1.0, square=True, cmap="Blues", linecolor='black', annot=True, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('work-balance-stars', 'culture-values-stars', 'carrer-opportunities-stars', 'comp-benefit-stars', 'senior-mangemnet-stars')
#
# During handling of the above exception, another exception occurred:
#
# ...
